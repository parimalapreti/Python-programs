# %%
#program to find sum of two numnbers using function
def sum(a,b):
    return a+b
x=sum(5,10)
print("sum:",x)
# Out:
# sum: 15

# %%
#program to find sum of two numbers taking from user
def sum(a,b):
    return a+b
a=int(input("enter a:"))
b=int(input("enter b:"))
print("sum=",a+b)
# Out:
# enter a: 10
# enter b: 20
# sum= 30

# %%
def sum(a,b):
    print("sum:",x)
x=sum(5,10)
# Out:
# sum: 15
