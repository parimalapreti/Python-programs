# %%
#find the largest number element in a list
numbers=[12,45,67,23,89,34]
largest=max(numbers)
print("list:",numbers)
print("largest number in a list:",largest)
# Out:
# list: [12, 45, 67, 23, 89, 34]
# largest number in a list: 89
