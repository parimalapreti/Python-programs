# %%
#program to calculate factorial of a number using recursion
def fact(num):
    if num==0 or num==1:
        return 1
    else:
        return num*fact(num-1)
n=int(input("Enter a num:"))
result=fact(n)
print("the fact of (n) is:",(result))
# Out:
# Enter a num: 5
# the fact of (n) is: 120
