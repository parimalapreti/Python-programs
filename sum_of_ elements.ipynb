# %%
#program to find sum of list elements using functions
def sumation(my_list):
    return sum(my_list)
my_list=[1,3,5,7]
x=sumation(my_list)
print(x)
# Out:
# 16

# %%
def summation(my_list):
    sum=0
    for i in my_list:
        sum=sum+1
    return sum
my_list=[1,2,3,4]
x=summation(my_list)
print(x)
# Out:
# 4
