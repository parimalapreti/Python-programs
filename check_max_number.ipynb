# %%
#program to find max of 3 numbers without using max function
def MAX(a,b,c):
    if a>b and a>c:
        print("a is maximum")
    elif b>a and b>c:
        print("b is maximum")
    else:
        print("c is maximum")
a=int(input("enter a:"))
b=int(input("enter b:"))
c=int(input("enter c:"))
MAX(a,b,c)
# Out:
# enter a: 3
# enter b: 4
# enter c: 1
# b is maximum

# %%
#program to find max of 3 numbers using max() function
def maximum(a,b,c):
    return max(a,b,c)
x=maximum(5,4,9)
print("maximum:",x)
# Out:
# maximum: 9
