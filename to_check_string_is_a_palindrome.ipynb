# %%
#program to check the string is a palindrome
def palindrome(Word):
   if Word[::-1]==Word:
    print("It is palidrome string:",Word)
   else:
    print("It is not a palindrome string:")
Word=input("enter a string:")
palindrome(Word)
# Out:
# enter a string: madam
# It is palidrome string: madam

# %%
#program to check the string is a palindrome using recursion
def palindrome(word):
    if len(word)<=1:
        return true
    if word[0]==word[-1]:
        return palindrome(word[1:-1])
    else:
        return false
text=input("enter a word:")
if(palindrome(text)):
    print("it is a palindrome:")
else:
    print("not a palindrome:")
# Out:
# enter a word: madam
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 10
#       8         return false
#       9 text=input("enter a word:")
# ---> 10 if(palindrome(text)):
#      11     print("it is a palindrome:")
#      12 else:
#
# Cell In[27], line 6, in palindrome(word)
#       4     return true
#       5 if word[0]==word[-1]:
# ----> 6     return palindrome(word[1:-1])
#       7 else:
#       8     return false
#
# Cell In[27], line 6, in palindrome(word)
#       4     return true
#       5 if word[0]==word[-1]:
# ----> 6     return palindrome(word[1:-1])
#       7 else:
#       8     return false
#
# Cell In[27], line 4, in palindrome(word)
#       2 def palindrome(word):
#       3     if len(word)<=1:
# ----> 4         return true
#       5     if word[0]==word[-1]:
#       6         return palindrome(word[1:-1])
#
# NameError: name 'true' is not defined
